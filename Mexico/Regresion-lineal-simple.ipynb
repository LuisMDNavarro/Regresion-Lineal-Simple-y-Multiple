# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %% [markdown]
# **Private_room**

# %%
#Cargar un archivo csv
df = pd.read_csv('Private_room.csv')

# Lista de variables independientes
vars_independientes = ['host_acceptance_rate', 'host_is_superhost', 'bathrooms', 
                       'review_scores_cleanliness', 'host_identity_verified', 'instant_bookable',
                       'property_type']
# Lista de variables dependiente
vars_dependientes = ['price', 'price', 'accommodates', 'price', 'price', 'price', 'price']
# DataFrame vacío para almacenar los coeficientes de correlacion R
heatmap_data = pd.DataFrame(index=vars_dependientes, columns=vars_independientes)
resultados = []
mayor_r = 0
mejor_modelo = {}

for var_indep, var_dep in zip(vars_independientes, vars_dependientes):
    Vars_Indep = df[[var_indep]] 
    Var_Dep = df[var_dep]
    #Se define model como la funcion de regresion lineal
    model = LinearRegression()
    #Ajustamos el modelo con las variables antes declaradas
    model.fit(X = Vars_Indep, y = Var_Dep)
    #Evaluamos la eficiencia del modelo obtenido por medio del coeficiente R Determinacion
    coef_Deter = model.score(X = Vars_Indep, y = Var_Dep)
    #Corroboramos cual es el coeficiente de Correlacion de nuestro modelo
    coef_Correl = np.sqrt(coef_Deter)
    # Guardar el valor en la matriz del heatmap
    heatmap_data.loc[var_dep, var_indep] = coef_Correl

    # Guardar en la lista de resultados
    resultados.append({
        "Variable dependiente": var_dep,
        "Variable independiente": var_indep,
        "R": coef_Correl,
        "R2": coef_Deter
    })

    # Si es la mejor correlación hasta ahora, guardamos el modelo
    if coef_Correl > mayor_r:
        mayor_r = coef_Correl
        mejor_modelo = {
            "var_dep": var_dep,
            "var_indep": var_indep,
            "a": model.coef_[0],
            "b": model.intercept_,
            "R": coef_Correl,
            "R2": coef_Deter
        }

# Convertir resultados a DataFrame y ordenar por R descendente
df_resultados = pd.DataFrame(resultados).sort_values(by="R", ascending=False)
#Eliminar filas repetidas
heatmap_data = heatmap_data[~heatmap_data.index.duplicated(keep='first')]
# Convertir valores a tipo numérico (pueden ser strings por NaN)
heatmap_data = heatmap_data.astype(float)

#Mapa de calor
plt.figure(figsize=(10, 2.5))
sns.heatmap(heatmap_data, annot=True, cmap="coolwarm", fmt=".4f", linewidths=0.5)
plt.title("Coeficiente de Correlación (R)")
plt.xlabel("Variables Independientes")
plt.ylabel("Variables Dependientes")
plt.show()

# Tabla de resultados
print("Tabla de Resultados (R y R^2)")
print(df_resultados.to_string(index=False))
print("\n\n")

#Modelo matematico
print(mejor_modelo['var_dep'], " vs ", mejor_modelo['var_indep'])
print(f"Modelo matemático: y = {mejor_modelo['a']:.4f}x + {mejor_modelo['b']:.4f}")
print(f"Correlación R: {mejor_modelo['R']:.4f} | Determinación R^2: {mejor_modelo['R2']:.4f}")
# Out:
# Tabla de Resultados (R y R^2)
# Variable dependiente    Variable independiente        R       R2
#                price review_scores_cleanliness 0.132094 0.017449
#                price             property_type 0.128424 0.016493
#                price    host_identity_verified 0.127463 0.016247
#                price          instant_bookable 0.113720 0.012932
#         accommodates                 bathrooms 0.082154 0.006749
#                price         host_is_superhost 0.054580 0.002979
#                price      host_acceptance_rate 0.046312 0.002145
#
#
#
# price  vs  review_scores_cleanliness
# Modelo matemático: y = 467.2628x + -1534.7046
# Correlación R: 0.1321 | Determinación R^2: 0.0174

# %%
df_resultados
# Out:
#   Variable dependiente     Variable independiente         R        R2
# 3                price  review_scores_cleanliness  0.132094  0.017449
# 6                price              property_type  0.128424  0.016493
# 4                price     host_identity_verified  0.127463  0.016247
# 5                price           instant_bookable  0.113720  0.012932
# 2         accommodates                  bathrooms  0.082154  0.006749
# 1                price          host_is_superhost  0.054580  0.002979
# 0                price       host_acceptance_rate  0.046312  0.002145

# %% [markdown]
# **Entire home/apt**

# %%
#Cargar un archivo csv
df = pd.read_csv('Entire_home_apt.csv')

# Lista de variables independientes
vars_independientes = ['host_acceptance_rate', 'host_is_superhost', 'bathrooms', 
                       'review_scores_cleanliness', 'host_identity_verified', 'instant_bookable',
                       'property_type']
# Lista de variables dependiente
vars_dependientes = ['price', 'price', 'accommodates', 'price', 'price', 'price', 'price']
# DataFrame vacío para almacenar los coeficientes de correlacion R
heatmap_data = pd.DataFrame(index=vars_dependientes, columns=vars_independientes)
resultados = []
mayor_r = 0
mejor_modelo = {}

for var_indep, var_dep in zip(vars_independientes, vars_dependientes):
    Vars_Indep = df[[var_indep]] 
    Var_Dep = df[var_dep]
    #Se define model como la funcion de regresion lineal
    model = LinearRegression()
    #Ajustamos el modelo con las variables antes declaradas
    model.fit(X = Vars_Indep, y = Var_Dep)
    #Evaluamos la eficiencia del modelo obtenido por medio del coeficiente R Determinacion
    coef_Deter = model.score(X = Vars_Indep, y = Var_Dep)
    #Corroboramos cual es el coeficiente de Correlacion de nuestro modelo
    coef_Correl = np.sqrt(coef_Deter)
    # Guardar el valor en la matriz del heatmap
    heatmap_data.loc[var_dep, var_indep] = coef_Correl

    # Guardar en la lista de resultados
    resultados.append({
        "Variable dependiente": var_dep,
        "Variable independiente": var_indep,
        "R": coef_Correl,
        "R2": coef_Deter
    })

    # Si es la mejor correlación hasta ahora, guardamos el modelo
    if coef_Correl > mayor_r:
        mayor_r = coef_Correl
        mejor_modelo = {
            "var_dep": var_dep,
            "var_indep": var_indep,
            "a": model.coef_[0],
            "b": model.intercept_,
            "R": coef_Correl,
            "R2": coef_Deter
        }

# Convertir resultados a DataFrame y ordenar por R descendente
df_resultados = pd.DataFrame(resultados).sort_values(by="R", ascending=False)
#Eliminar filas repetidas
heatmap_data = heatmap_data[~heatmap_data.index.duplicated(keep='first')]
# Convertir valores a tipo numérico (pueden ser strings por NaN)
heatmap_data = heatmap_data.astype(float)

#Mapa de calor
plt.figure(figsize=(10, 2.5))
sns.heatmap(heatmap_data, annot=True, cmap="coolwarm", fmt=".4f", linewidths=0.5)
plt.title("Coeficiente de Correlación (R)")
plt.xlabel("Variables Independientes")
plt.ylabel("Variables Dependientes")
plt.show()

# Tabla de resultados
print("Tabla de Resultados (R y R^2)")
print(df_resultados.to_string(index=False))
print("\n\n")

#Modelo matematico
print(mejor_modelo['var_dep'], " vs ", mejor_modelo['var_indep'])
print(f"Modelo matemático: y = {mejor_modelo['a']:.4f}x + {mejor_modelo['b']:.4f}")
print(f"Correlación R: {mejor_modelo['R']:.4f} | Determinación R^2: {mejor_modelo['R2']:.4f}")
# Out:
# Tabla de Resultados (R y R^2)
# Variable dependiente    Variable independiente        R       R2
#         accommodates                 bathrooms 0.425556 0.181098
#                price          instant_bookable 0.098452 0.009693
#                price             property_type 0.097021 0.009413
#                price review_scores_cleanliness 0.083988 0.007054
#                price         host_is_superhost 0.049606 0.002461
#                price      host_acceptance_rate 0.045284 0.002051
#                price    host_identity_verified 0.035025 0.001227
#
#
#
# accommodates  vs  bathrooms
# Modelo matemático: y = 1.0132x + 2.0177
# Correlación R: 0.4256 | Determinación R^2: 0.1811

# %%
df_resultados
# Out:
#   Variable dependiente     Variable independiente         R        R2
# 2         accommodates                  bathrooms  0.425556  0.181098
# 5                price           instant_bookable  0.098452  0.009693
# 6                price              property_type  0.097021  0.009413
# 3                price  review_scores_cleanliness  0.083988  0.007054
# 1                price          host_is_superhost  0.049606  0.002461
# 0                price       host_acceptance_rate  0.045284  0.002051
# 4                price     host_identity_verified  0.035025  0.001227

# %% [markdown]
# **Hotel room**

# %%
#Cargar un archivo csv
df = pd.read_csv('Hotel_room.csv')

# Lista de variables independientes
vars_independientes = ['host_acceptance_rate', 'host_is_superhost', 'bathrooms', 
                       'review_scores_cleanliness', 'host_identity_verified', 'instant_bookable',
                       'property_type']
# Lista de variables dependiente
vars_dependientes = ['price', 'price', 'accommodates', 'price', 'price', 'price', 'price']
# DataFrame vacío para almacenar los coeficientes de correlacion R
heatmap_data = pd.DataFrame(index=vars_dependientes, columns=vars_independientes)
resultados = []
mayor_r = 0
mejor_modelo = {}

for var_indep, var_dep in zip(vars_independientes, vars_dependientes):
    Vars_Indep = df[[var_indep]] 
    Var_Dep = df[var_dep]
    #Se define model como la funcion de regresion lineal
    model = LinearRegression()
    #Ajustamos el modelo con las variables antes declaradas
    model.fit(X = Vars_Indep, y = Var_Dep)
    #Evaluamos la eficiencia del modelo obtenido por medio del coeficiente R Determinacion
    coef_Deter = model.score(X = Vars_Indep, y = Var_Dep)
    #Corroboramos cual es el coeficiente de Correlacion de nuestro modelo
    coef_Correl = np.sqrt(coef_Deter)
    # Guardar el valor en la matriz del heatmap
    heatmap_data.loc[var_dep, var_indep] = coef_Correl

    # Guardar en la lista de resultados
    resultados.append({
        "Variable dependiente": var_dep,
        "Variable independiente": var_indep,
        "R": coef_Correl,
        "R2": coef_Deter
    })

    # Si es la mejor correlación hasta ahora, guardamos el modelo
    if coef_Correl > mayor_r:
        mayor_r = coef_Correl
        mejor_modelo = {
            "var_dep": var_dep,
            "var_indep": var_indep,
            "a": model.coef_[0],
            "b": model.intercept_,
            "R": coef_Correl,
            "R2": coef_Deter
        }

# Convertir resultados a DataFrame y ordenar por R descendente
df_resultados = pd.DataFrame(resultados).sort_values(by="R", ascending=False)
#Eliminar filas repetidas
heatmap_data = heatmap_data[~heatmap_data.index.duplicated(keep='first')]
# Convertir valores a tipo numérico (pueden ser strings por NaN)
heatmap_data = heatmap_data.astype(float)

#Mapa de calor
plt.figure(figsize=(10, 2.5))
sns.heatmap(heatmap_data, annot=True, cmap="coolwarm", fmt=".4f", linewidths=0.5)
plt.title("Coeficiente de Correlación (R)")
plt.xlabel("Variables Independientes")
plt.ylabel("Variables Dependientes")
plt.show()

# Tabla de resultados
print("Tabla de Resultados (R y R^2)")
print(df_resultados.to_string(index=False))
print("\n\n")

#Modelo matematico
print(mejor_modelo['var_dep'], " vs ", mejor_modelo['var_indep'])
print(f"Modelo matemático: y = {mejor_modelo['a']:.4f}x + {mejor_modelo['b']:.4f}")
print(f"Correlación R: {mejor_modelo['R']:.4f} | Determinación R^2: {mejor_modelo['R2']:.4f}")
# Out:
# Tabla de Resultados (R y R^2)
# Variable dependiente    Variable independiente        R       R2
#                price             property_type 0.192488 0.037052
#                price    host_identity_verified 0.130004 0.016901
#                price          instant_bookable 0.106826 0.011412
#         accommodates                 bathrooms 0.095411 0.009103
#                price review_scores_cleanliness 0.087851 0.007718
#                price         host_is_superhost 0.077467 0.006001
#                price      host_acceptance_rate 0.001409 0.000002
#
#
#
# price  vs  property_type
# Modelo matemático: y = 6.6788x + 271.0917
# Correlación R: 0.1925 | Determinación R^2: 0.0371

# %%
df_resultados
# Out:
#   Variable dependiente     Variable independiente         R        R2
# 6                price              property_type  0.192488  0.037052
# 4                price     host_identity_verified  0.130004  0.016901
# 5                price           instant_bookable  0.106826  0.011412
# 2         accommodates                  bathrooms  0.095411  0.009103
# 3                price  review_scores_cleanliness  0.087851  0.007718
# 1                price          host_is_superhost  0.077467  0.006001
# 0                price       host_acceptance_rate  0.001409  0.000002

# %% [markdown]
# **Shared room**

# %%
#Cargar un archivo csv
df = pd.read_csv('Shared_room.csv')

# Lista de variables independientes
vars_independientes = ['host_acceptance_rate', 'host_is_superhost', 'bathrooms', 
                       'review_scores_cleanliness', 'host_identity_verified', 'instant_bookable',
                       'property_type']
# Lista de variables dependiente
vars_dependientes = ['price', 'price', 'accommodates', 'price', 'price', 'price', 'price']
# DataFrame vacío para almacenar los coeficientes de correlacion R
heatmap_data = pd.DataFrame(index=vars_dependientes, columns=vars_independientes)
resultados = []
mayor_r = 0
mejor_modelo = {}

for var_indep, var_dep in zip(vars_independientes, vars_dependientes):
    Vars_Indep = df[[var_indep]] 
    Var_Dep = df[var_dep]
    #Se define model como la funcion de regresion lineal
    model = LinearRegression()
    #Ajustamos el modelo con las variables antes declaradas
    model.fit(X = Vars_Indep, y = Var_Dep)
    #Evaluamos la eficiencia del modelo obtenido por medio del coeficiente R Determinacion
    coef_Deter = model.score(X = Vars_Indep, y = Var_Dep)
    #Corroboramos cual es el coeficiente de Correlacion de nuestro modelo
    coef_Correl = np.sqrt(coef_Deter)
    # Guardar el valor en la matriz del heatmap
    heatmap_data.loc[var_dep, var_indep] = coef_Correl

    # Guardar en la lista de resultados
    resultados.append({
        "Variable dependiente": var_dep,
        "Variable independiente": var_indep,
        "R": coef_Correl,
        "R2": coef_Deter
    })

    # Si es la mejor correlación hasta ahora, guardamos el modelo
    if coef_Correl > mayor_r:
        mayor_r = coef_Correl
        mejor_modelo = {
            "var_dep": var_dep,
            "var_indep": var_indep,
            "a": model.coef_[0],
            "b": model.intercept_,
            "R": coef_Correl,
            "R2": coef_Deter
        }

# Convertir resultados a DataFrame y ordenar por R descendente
df_resultados = pd.DataFrame(resultados).sort_values(by="R", ascending=False)
#Eliminar filas repetidas
heatmap_data = heatmap_data[~heatmap_data.index.duplicated(keep='first')]
# Convertir valores a tipo numérico (pueden ser strings por NaN)
heatmap_data = heatmap_data.astype(float)

#Mapa de calor
plt.figure(figsize=(10, 2.5))
sns.heatmap(heatmap_data, annot=True, cmap="coolwarm", fmt=".4f", linewidths=0.5)
plt.title("Coeficiente de Correlación (R)")
plt.xlabel("Variables Independientes")
plt.ylabel("Variables Dependientes")
plt.show()

# Tabla de resultados
print("Tabla de Resultados (R y R^2)")
print(df_resultados.to_string(index=False))
print("\n\n")

#Modelo matematico
print(mejor_modelo['var_dep'], " vs ", mejor_modelo['var_indep'])
print(f"Modelo matemático: y = {mejor_modelo['a']:.4f}x + {mejor_modelo['b']:.4f}")
print(f"Correlación R: {mejor_modelo['R']:.4f} | Determinación R^2: {mejor_modelo['R2']:.4f}")
# Out:
# Tabla de Resultados (R y R^2)
# Variable dependiente    Variable independiente        R       R2
#         accommodates                 bathrooms 0.614600 0.377733
#                price             property_type 0.241755 0.058445
#                price    host_identity_verified 0.227473 0.051744
#                price review_scores_cleanliness 0.182692 0.033376
#                price      host_acceptance_rate 0.144428 0.020859
#                price         host_is_superhost 0.096146 0.009244
#                price          instant_bookable 0.056821 0.003229
#
#
#
# accommodates  vs  bathrooms
# Modelo matemático: y = 1.4610x + 0.8777
# Correlación R: 0.6146 | Determinación R^2: 0.3777

# %%
df_resultados
# Out:
#   Variable dependiente     Variable independiente         R        R2
# 2         accommodates                  bathrooms  0.614600  0.377733
# 6                price              property_type  0.241755  0.058445
# 4                price     host_identity_verified  0.227473  0.051744
# 3                price  review_scores_cleanliness  0.182692  0.033376
# 0                price       host_acceptance_rate  0.144428  0.020859
# 1                price          host_is_superhost  0.096146  0.009244
# 5                price           instant_bookable  0.056821  0.003229
