# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
#Cargar un archivo csv
df = pd.read_csv('50_sin_nulos_ni_atipicos_Chicago_Illinois_UnitedStates.csv')
df = df.drop(['Unnamed: 0'], axis = 1)
df = df.select_dtypes(include=['number'])
#Encontramos todas las correlaciones entre las variables
Corr_Factors = df.corr()
#Encontramos el valor absoluto de todas las correlaciones entre las variables
Corr_Factors1 = abs(Corr_Factors)
#Graficamos el mapa de calor de los coeficientes de correlacion
plt.figure(figsize=(17, 11))
Head_Map = sns.heatmap(Corr_Factors1, cmap = 'Blues', annot = True, fmt = ".2f")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8269 entries, 0 to 8268
# Data columns (total 31 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   host_acceptance_rate         8269 non-null   float64
#  1   price                        8269 non-null   float64
#  2   host_id                      8269 non-null   int64
#  3   host_acceptance_rate.1       8269 non-null   float64
#  4   host_total_listings_count    8269 non-null   float64
#  5   latitude                     8269 non-null   float64
#  6   longitude                    8269 non-null   float64
#  7   accommodates                 8269 non-null   float64
#  8   bathrooms                    8269 non-null   float64
#  9   bedrooms                     8269 non-null   float64
#  10  beds                         8269 non-null   float64
#  11  price.1                      8269 non-null   float64
# ...

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep= df[['availability_60', 'availability_90','availability_30']]
Var_Dep= df['host_id']
#Se define model como la función de regresión lineal
model= LinearRegression()
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
print(f"Correlación R: {coef_Correl:.4f} | Determinación R^2: {coef_Deter:.4f}")
# Out:
# Correlación R: 0.2598 | Determinación R^2: 0.0675

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep= df[['availability_60', 'availability_90','availability_30']]
Var_Dep= df['host_id']
#Se define model como la función de regresión lineal
model= LinearRegression()
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
print(f"Correlación R: {coef_Correl:.4f} | Determinación R^2: {coef_Deter:.4f}")
