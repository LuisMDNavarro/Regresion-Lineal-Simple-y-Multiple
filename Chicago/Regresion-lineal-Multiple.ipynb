# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
#Cargar un archivo csv
df = pd.read_csv('All_rooms.csv')
df = df.drop(['Unnamed: 0'], axis = 1)
df = df.select_dtypes(include=['number'])
#Encontramos todas las correlaciones entre las variables
Corr_Factors = df.corr()
#Encontramos el valor absoluto de todas las correlaciones entre las variables
Corr_Factors1 = abs(Corr_Factors)
#Graficamos el mapa de calor de los coeficientes de correlacion
plt.figure(figsize=(20, 11))
Head_Map = sns.heatmap(Corr_Factors1, cmap = 'Blues', annot = True, fmt = ".2f")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8269 entries, 0 to 8268
# Data columns (total 34 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   host_is_superhost            8269 non-null   int64
#  1   host_identity_verified       8269 non-null   int64
#  2   property_type                8269 non-null   int64
#  3   room_type                    8269 non-null   int64
#  4   instant_bookable             8269 non-null   int64
#  5   host_id                      8269 non-null   int64
#  6   host_acceptance_rate         8269 non-null   float64
#  7   host_total_listings_count    8269 non-null   float64
#  8   latitude                     8269 non-null   float64
#  9   longitude                    8269 non-null   float64
#  10  accommodates                 8269 non-null   float64
#  11  bathrooms                    8269 non-null   float64
#  12  bedrooms                     8269 non-null   float64
# ...

# %% [markdown]
# **host_id**

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
#Vars_Indep = df.drop(columns=['host_id'])
Vars_Indep= df[['availability_60', 'availability_90','availability_30', 'review_scores_checkin', 'number_of_reviews']]
Var_Dep= df['host_id']
#Se define model como la función de regresión lineal
model= LinearRegression()
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
print(f"Correlación R: {coef_Correl:.4f} | Determinación R^2: {coef_Deter:.4f}")
# Out:
# Correlación R: 0.3312 | Determinación R^2: 0.1097

# %% [markdown]
# **host_acceptance_rate**

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep= df[['minimum_nights_avg_ntm', 'instant_bookable', 'number_of_reviews_ltm', 'number_of_reviews_l30d', 'reviews_per_month']]
Var_Dep= df['host_acceptance_rate']
#Se define model como la función de regresión lineal
model= LinearRegression()
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
print(f"Correlación R: {coef_Correl:.4f} | Determinación R^2: {coef_Deter:.4f}")
# Out:
# Correlación R: 0.2872 | Determinación R^2: 0.0825

# %% [markdown]
# **host_is_superhost**

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep= df[['number_of_reviews', 'number_of_reviews_ltm', 'number_of_reviews_l30d', 'review_scores_rating', 'review_scores_checkin']]
Var_Dep= df['host_is_superhost']
#Se define model como la función de regresión lineal
model= LinearRegression()
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
print(f"Correlación R: {coef_Correl:.4f} | Determinación R^2: {coef_Deter:.4f}")
# Out:
# Correlación R: 0.4605 | Determinación R^2: 0.2120

# %% [markdown]
# **host_total_listings_count**

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep= df[['longitude', 'instant_bookable', 'availability_365', 'review_scores_checkin', 'availability_30']]
Var_Dep= df['host_total_listings_count']
#Se define model como la función de regresión lineal
model= LinearRegression()
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
print(f"Correlación R: {coef_Correl:.4f} | Determinación R^2: {coef_Deter:.4f}")
# Out:
# Correlación R: 0.2896 | Determinación R^2: 0.0839

# %% [markdown]
# **room_type**

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep= df[['property_type', 'accommodates', 'price', 'beds', 'bedrooms']]
Var_Dep= df['room_type']
#Se define model como la función de regresión lineal
model= LinearRegression()
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
print(f"Correlación R: {coef_Correl:.4f} | Determinación R^2: {coef_Deter:.4f}")
# Out:
# Correlación R: 0.5952 | Determinación R^2: 0.3543

# %% [markdown]
# **accommodates**

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep= df[['beds', 'bedrooms', 'bathrooms', 'price', 'room_type']]
Var_Dep= df['accommodates']
#Se define model como la función de regresión lineal
model= LinearRegression()
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
print(f"Correlación R: {coef_Correl:.4f} | Determinación R^2: {coef_Deter:.4f}")
# Out:
# Correlación R: 0.8187 | Determinación R^2: 0.6703

# %% [markdown]
# **bedrooms**

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep= df[['beds', 'accommodates', 'bathrooms', 'price', 'room_type']]
Var_Dep= df['bedrooms']
#Se define model como la función de regresión lineal
model= LinearRegression()
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
print(f"Correlación R: {coef_Correl:.4f} | Determinación R^2: {coef_Deter:.4f}")
# Out:
# Correlación R: 0.6437 | Determinación R^2: 0.4143

# %% [markdown]
# **price**

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep= df[['beds', 'accommodates', 'bathrooms', 'bedrooms', 'room_type']]
Var_Dep= df['price']
#Se define model como la función de regresión lineal
model= LinearRegression()
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
print(f"Correlación R: {coef_Correl:.4f} | Determinación R^2: {coef_Deter:.4f}")
# Out:
# Correlación R: 0.4539 | Determinación R^2: 0.2060

# %% [markdown]
# **review_scores_value**

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep= df[['review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_communication', 'review_scores_checkin']]
Var_Dep= df['review_scores_value']
#Se define model como la función de regresión lineal
model= LinearRegression()
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
print(f"Correlación R: {coef_Correl:.4f} | Determinación R^2: {coef_Deter:.4f}")
# Out:
# Correlación R: 0.6967 | Determinación R^2: 0.4854

# %% [markdown]
# **reviews_per_month**

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep= df[['number_of_reviews_ltm', 'number_of_reviews_l30d']]
Var_Dep= df['reviews_per_month']
#Se define model como la función de regresión lineal
model= LinearRegression()
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
print(f"Correlación R: {coef_Correl:.4f} | Determinación R^2: {coef_Deter:.4f}")
# Out:
# Correlación R: 0.6174 | Determinación R^2: 0.3812
